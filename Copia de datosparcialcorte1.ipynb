# %%
from google.colab import drive
drive.mount('/content/gdrive')
import sys
sys.path.append('/content/gdrive/My Drive/clonparcial')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
from os.path import join

# %%
ROOT = '/content/drive'
PROJ = 'My Drive/parcialcte1'
GIT_USERNAME = "ogils"
GIT_TOKEN = "5ee5bf5ce470e2df8d150e726d0d56f2f19d70a0"
GIT_REPOSITORY = "fiscompunipamplona/fc2-exam-primercorte2020i-ogils"
GIT_PATH = "https://5ee5bf5ce470e2df8d150e726d0d56f2f19d70a0@github.com/fiscompunipamplona/fc2-exam-primercorte2020i-ogils.git"
drive.mount(ROOT)
# Out:
# Mounted at /content/drive

# %%
PROJECT_PATH = join(ROOT, PROJ)
# !mkdir "{PROJECT_PATH}"
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/parcialcte1’: File exists

# %%
PROJECT_PATH = join(ROOT, PROJ)
# !git clone "{GIT_PATH}"
# !rsync -aP fc2-exam-primercorte2020i-ogils "{PROJECT_PATH}"
# Out:
# fatal: destination path 'fc2-exam-primercorte2020i-ogils' already exists and is not an empty directory.
# sending incremental file list
# fc2-exam-primercorte2020i-ogils/
# fc2-exam-primercorte2020i-ogils/.git/
# fc2-exam-primercorte2020i-ogils/.git/config
#             339 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=46/53)
# fc2-exam-primercorte2020i-ogils/.git/index
#             345 100%  336.91kB/s    0:00:00 (xfr#2, to-chk=44/53)
# fc2-exam-primercorte2020i-ogils/.git/packed-refs
#             114 100%  111.33kB/s    0:00:00 (xfr#3, to-chk=43/53)
# fc2-exam-primercorte2020i-ogils/.git/branches/
# fc2-exam-primercorte2020i-ogils/.git/hooks/
# fc2-exam-primercorte2020i-ogils/.git/info/
# fc2-exam-primercorte2020i-ogils/.git/logs/
# fc2-exam-primercorte2020i-ogils/.git/logs/refs/
# fc2-exam-primercorte2020i-ogils/.git/logs/refs/heads/
# fc2-exam-primercorte2020i-ogils/.git/logs/refs/remotes/
# fc2-exam-primercorte2020i-ogils/.git/logs/refs/remotes/origin/
# ...

# %%
# %cd"{PROJECT_PATH}"/fc2-exam-primercorte2020i-ogils/
# !ls
# !git config --global user.email "ogils1996@gmail.com"
# !git config --global user.name "ogils"

# !git remote rm origin

# !git config --global github.user "{GIT_USERNAME}"
# !git config --global github.token "{GIT_TOKEN}"

# !git add *
# !git commit -m "parcial resuelto cte1"
# !git remote add origin https://"{GIT_TOKEN}"@github.com/"{GIT_REPOSITORY}"
# !git push -u origin master
# Out:
# /content/drive/My Drive/parcialcte1/fc2-exam-primercorte2020i-ogils
#  Casos1_13abr2020.csv		      parcialmomento.py
# 'Copia de datosparcialcorte1.ipynb'  'parcial parte 2.ipynb'
#  fc2_exam_primerCorte2020i.ipynb      planets_2020.04.13_08.06.56.tab
#  momento.py			      planets_2020.04.13_08.06.56.tab.gsheet
#  parcialcorte1pt1.ipynb		      __pycache__
# 'parcial dataPandas.ipynb'
# error: open("planets_2020.04.13_08.06.56.tab.gsheet"): Operation not supported
# error: unable to index file planets_2020.04.13_08.06.56.tab.gsheet
# fatal: adding files failed
# On branch master
# Untracked files:
# 	Copia de datosparcialcorte1.ipynb
# 	__pycache__/
# 	momento.py
# 	parcial dataPandas.ipynb
# 	parcial parte 2.ipynb
# 	parcialcorte1pt1.ipynb
# 	parcialmomento.py
# 	planets_2020.04.13_08.06.56.tab.gsheet
#
# nothing added to commit but untracked files present
# Branch 'master' set up to track remote branch 'master' from 'origin'.
# Everything up-to-date
